# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
a = 'This is a good movie ever seen'
sid.polarity_scores(a)
# Out:
# {'compound': 0.4404, 'neg': 0.0, 'neu': 0.633, 'pos': 0.367}

# %%
a = 'This was the worst film to ever disgrace the screen'
sid.polarity_scores(a)
# Out:
# {'compound': -0.8074, 'neg': 0.477, 'neu': 0.523, 'pos': 0.0}

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-510fe97c-2fe5-40ad-b1fe-cc7b549a335c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-510fe97c-2fe5-40ad-b1fe-cc7b549a335c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving amazon.tsv to amazon.tsv
# User uploaded file "amazon.tsv" with length 4496991 bytes

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('amazon.tsv', sep ='\t')
df.head()
# Out:
#    Unnamed: 0 label                                             review
# 0           0   pos  Stuning even for the non-gamer: This sound tra...
# 1           1   pos  The best soundtrack ever to anything.: I'm rea...
# 2           2   pos  Amazing!: This soundtrack is my favorite music...
# 3           3   pos  Excellent Soundtrack: I truly like this soundt...
# 4           4   pos  Remember, Pull Your Jaw Off The Floor After He...

# %%
df['label'].value_counts()
# Out:
# neg    5097
# pos    4903
# Name: label, dtype: int64

# %%
df['label'].isnull().sum()
# Out:
# 0

# %%
df.dropna(inplace=True)

#blanks = []  # start with an empty list
#for i,lb,rv in df.itertuples():  # iterate over the DataFrame
   # if type(rv)==str:            # avoid NaN values
       # if rv.isspace():         # test 'review' for whitespace
           # blanks.append(i)     # add matching index numbers to the list

#df.drop(blanks, inplace=True)

# %%
sid.polarity_scores(df.iloc[0]['review'])
# Out:
# {'compound': 0.9454, 'neg': 0.088, 'neu': 0.669, 'pos': 0.243}

# %%
df['score'] = df['review'].apply(lambda review : sid.polarity_scores(review))
df.head()
# Out:
#    Unnamed: 0  ...                                              score
# 0           0  ...  {'neg': 0.088, 'neu': 0.669, 'pos': 0.243, 'co...
# 1           1  ...  {'neg': 0.018, 'neu': 0.837, 'pos': 0.145, 'co...
# 2           2  ...  {'neg': 0.04, 'neu': 0.692, 'pos': 0.268, 'com...
# 3           3  ...  {'neg': 0.09, 'neu': 0.615, 'pos': 0.295, 'com...
# 4           4  ...  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
#
# [5 rows x 4 columns]

# %%
df['compound'] = df['score'].apply(lambda score_dict: score_dict['compound'])
df.head()
# Out:
#    Unnamed: 0  ... compound
# 0           0  ...   0.9454
# 1           1  ...   0.8957
# 2           2  ...   0.9858
# 3           3  ...   0.9814
# 4           4  ...   0.9781
#
# [5 rows x 5 columns]

# %%
df['comp_score'] = df['compound'].apply(lambda c: 'pos' if c >= 0 else 'neg')
df.head()
# Out:
#    Unnamed: 0 label  ... compound comp_score
# 0           0   pos  ...   0.9454        pos
# 1           1   pos  ...   0.8957        pos
# 2           2   pos  ...   0.9858        pos
# 3           3   pos  ...   0.9814        pos
# 4           4   pos  ...   0.9781        pos
#
# [5 rows x 6 columns]

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print(classification_report(df['label'],df['comp_score']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.86      0.51      0.64      5097
#          pos       0.64      0.91      0.75      4903
#
#     accuracy                           0.71     10000
#    macro avg       0.75      0.71      0.70     10000
# weighted avg       0.75      0.71      0.70     10000

# %%
print(confusion_matrix(df['label'],df['comp_score']))
# Out:
# [[2623 2474]
#  [ 435 4468]]

# %%
accuracy_score(df['label'],df['comp_score'])
# Out:
# 0.7091
